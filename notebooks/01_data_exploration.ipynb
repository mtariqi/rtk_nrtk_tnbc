# %% [markdown]
# # RTK-NRTK TNBC Data Exploration## Loading and Exploring TCGA Expression Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../src')
from bioinformatics.kinase_utils import RTK_GENES, NRTK_GENES

print(f'RTK genes: {len(RTK_GENES)}')
print(f'NRTK genes: {len(NRTK_GENES)}')
